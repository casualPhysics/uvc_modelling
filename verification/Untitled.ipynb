# %%
from photompy import *
# have i parsed these things correctly? 

lampdict = read_ies_data('../USHIO_B1_(PRERELEASE_DATA).ies')
lampdict['inter']
# Out:
# {'thetas': array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ,
#         27.5, 30. , 32.5, 35. , 37.5, 40. , 42.5, 45. , 47.5, 50. , 52.5,
#         55. , 57.5, 60. , 62.5, 65. , 67.5, 70. , 72.5, 75. , 77.5, 80. ,
#         82.5, 85. , 87.5, 90. ]),
#  'phis': array([  0. ,  22.5,  45. ,  67.5,  90. , 112.5, 135. , 157.5, 180. ,
#         202.5, 225. , 247.5, 270. , 292.5, 315. , 337.5, 360. ]),
#  'values': array([[121.38, 121.88, 121.77, 120.72, 119.28, 116.91, 114.23, 110.78,
#          105.98,  98.26,  86.66,  74.6 ,  60.36,  45.75,  32.74,  21.8 ,
#           12.91,   7.21,   4.07,   2.62,   1.56,   1.08,   0.52,   0.65,
#            0.71,   0.76,   0.72,   0.55,   0.43,   0.32,   0.3 ,   0.38,
#            0.  ,   0.24,   0.2 ,   0.  ,   0.  ],
#         [121.65, 122.27, 121.63, 120.31, 118.99, 116.88, 114.34, 111.4 ,
#          107.05, 100.57,  89.12,  76.31,  63.5 ,  49.3 ,  35.58,  24.03,
# ...

# %%
import sys 
sys.path.append('../')
import ies_render
data_test = (ies_render.IES_Parser('/Users/afiqhatta/uvc_lighting/USHIO_B1_(PRERELEASE_DATA).ies'))
data_test._ies_data.candela_values
data_test
# Out:
# IES file: /Users/afiqhatta/uvc_lighting/USHIO_B1_(PRERELEASE_DATA).ies
# Shape:	rectangular with luminous sides, L=0.045m, H=0.076m
# Vertical:
# 	0.0, 2.5, ... 90.0 [37 values]
# Horizontal:
# 	0.0, 22.5, ... 360.0 [17 values]
# Candela:
# 	0:	121.38, 121.88, 121.77, 120.72, 119.28, 116.91, 114.23, 110.78, 105.98, 98.26, 86.66, 74.6, 60.36, 45.75, 32.74, 21.8, 12.91, 7.21, 4.07, 2.62, 1.56, 1.08, 0.52, 0.65, 0.71, 0.76, 0.72, 0.55, 0.43, 0.32, 0.3, 0.38, 0.0, 0.24, 0.2, 0.0, 0.0
# 	...
#
# 	360:	121.38, 121.88, 121.77, 120.72, 119.28, 116.91, 114.23, 110.78, 105.98, 98.26, 86.66, 74.6, 60.36, 45.75, 32.74, 21.8, 12.91, 7.21, 4.07, 2.62, 1.56, 1.08, 0.52, 0.65, 0.71, 0.76, 0.72, 0.55, 0.43, 0.32, 0.3, 0.38, 0.0, 0.24, 0.2, 0.0, 0.0
